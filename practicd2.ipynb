# %% [markdown]
# Write a program to create a list with at least five elements and display it.
# Write a program to create a list containing different data types in a single list.
# Write a program to find the total number of elements in a list using the len() function.
# Write a program to access the first and last elements of a list using indexing.
# Write a program to replace an element at a specific index in a list.
# Write a program to extract a portion of a list using slicing.
# Write a program to concatenate two lists using the + operator.
# Write a program to repeat a list multiple times using the * operator.
# Write a program to add an element to the end of a list using the append() method.
# Write a program to insert an element at a specific index using the insert() method.
# Write a program to add multiple elements to a list using the extend() method.
# Write a program to remove a specific element from a list using the remove() method.
# Write a program to remove and return the last element of a list using the pop() method.
# Write a program to remove and return an element from a given index using the pop() method.
# Write a program to delete an element from a list using the del statement.
# Write a program to clear all elements from a list using the clear() method.
# Write a program to find the index of a specific element using the index() method.
# Write a program to count how many times a specific element appears in a list using the count() method.
# Write a program to sort the elements of a list in ascending order using the sort() method.
# Write a program to sort the elements of a list in descending order using the sort() method.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 np.zeroes
#
# NameError: name 'np' is not defined

# %% [markdown]
# Write a program to create a list with at least five elements and display it.

# %%
country = ["INDIA","AMERICA","CANADA","ITALY","CHINA","JAPAN"]
print(country)
# Out:
# ['INDIA', 'AMERICA', 'CANADA', 'ITALY', 'CHINA', 'JAPAN']

# %%
##Write a program to create a list containing different data types in a single list.
a = ["ram",4,3.4,True]
a
# Out:
# ['ram', 4, 3.4, True]

# %%
##rite a program to find the total number of elements in a list using the len() function.
len(a)
# Out:
# 4

# %%
#Write a program to access the first and last elements of a list using indexing.
print(country[0])
print(country[-1])
# Out:
# INDIA
# JAPAN

# %%
#Write a program to replace an element at a specific index in a list
country.insert(5,"pak")
print(country)
# Out:
# ['INDIA', 'AMERICA', 'CANADA', 'ITALY', 'CHINA', 'pak', 'JAPAN']

# %%
#Write a program to extract a portion of a list using slicing.
country[1:4]
# Out:
# ['AMERICA', 'CANADA', 'ITALY']

# %%
#Write a program to concatenate two lists using the + operator.
l = country + a
print(l)
# Out:
# ['INDIA', 'AMERICA', 'CANADA', 'ITALY', 'CHINA', 'pak', 'JAPAN', 'ram', 4, 3.4, True]

# %%
#Write a program to repeat a list multiple times using the * operator.
l*5
# Out:
# ['INDIA',
#  'AMERICA',
#  'CANADA',
#  'ITALY',
#  'CHINA',
#  'pak',
#  'JAPAN',
#  'ram',
#  4,
#  3.4,
#  True,
#  'INDIA',
#  'AMERICA',
#  'CANADA',
#  'ITALY',
#  'CHINA',
#  'pak',
#  'JAPAN',
#  'ram',
#  4,
#  3.4,
#  True,
#  'INDIA',
#  'AMERICA',
#  'CANADA',
#  'ITALY',
#  'CHINA',
#  'pak',
#  'JAPAN',
#  'ram',
#  4,
#  3.4,
#  True,
#  'INDIA',
#  'AMERICA',
#  'CANADA',
#  'ITALY',
#  'CHINA',
#  'pak',
#  'JAPAN',
#  'ram',
#  4,
#  3.4,
#  True,
#  'INDIA',
#  'AMERICA',
#  'CANADA',
#  'ITALY',
#  'CHINA',
#  'pak',
#  'JAPAN',
#  'ram',
#  4,
#  3.4,
#  True]
