# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\kashi\OneDrive\图片\Desktop\techcadd\loan_approval.csv")
df.head()
# Out:
#               name              city  income  credit_score  loan_amount  \
# 0     Allison Hill         East Jill  113810           389        39698
# 1     Brandon Hall     New Jamesside   44592           729        15446
# 2     Rhonda Smith      Lake Roberto   33278           584        11189
# 3  Gabrielle Davis  West Melanieview  127196           344        48823
# 4     Valerie Gray         Mariastad   66048           496        47174
#
#    years_employed  points  loan_approved
# 0              27    50.0          False
# 1              28    55.0          False
# 2              13    45.0          False
# 3              29    50.0          False
# 4               4    25.0          False

# %%
from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()
df['name'] =le.fit_transform(df['name'])
df['city'] =le.fit_transform(df['city'])
df
# Out:
#       name  city  income  credit_score  loan_amount  years_employed  points  \
# 0       46   326  113810           389        39698              27    50.0
# 1      218   989   44592           729        15446              28    55.0
# 2     1605   763   33278           584        11189              13    45.0
# 3      674  1793  127196           344        48823              29    50.0
# 4     1934   841   66048           496        47174               4    25.0
# ...    ...   ...     ...           ...          ...             ...     ...
# 1995   772  1418   92163           770        12251              13    85.0
# 1996   548   981   38799           635        48259              17    40.0
# 1997   221   308   41957           763        16752               5    60.0
# 1998   804     2  139022           360        24031              35    55.0
# 1999  1496  1032   41188           482        31397               6    20.0
#
#       loan_approved
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 1995           True
# 1996          False
# 1997           True
# 1998          False
# 1999          False
#
# [2000 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['name', 'city', 'income', 'credit_score', 'loan_amount',
#        'years_employed', 'points', 'loan_approved'],
#       dtype='object')

# %%
x =df[['name', 'city', 'income', 'credit_score', 'loan_amount',
       'years_employed', 'points']]

# %%
y =df['loan_approved']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
dc = DecisionTreeClassifier(max_depth=5)

# %%
dc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
pre = dc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pre)*100
# Out:
# 100.0
