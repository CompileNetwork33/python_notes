# %%
import seaborn as sns

# %%
df=sns.load_dataset("planets")
df.head(6)

# %%
df.isna().sum()

# %%
df.shape

# %%
df.describe

# %%
df.dtypes

# %%
df["orbital_period"].unique

# %%
df["orbital_period"]= df["orbital_period"].fillna(df["orbital_period"].mean())
df["orbital_period"]
df.isna().sum()

# %%
df.duplicated().sum()

# %%
df.drop_duplicates(inplace=True)

# %%
df["mass"].unique()

# %%
df["mass"]=df["mass"].fillna(df["mass"].mean())
df["mass"]
df.isna().sum()

# %%
df["distance"] = df["distance"].fillna(df["distance"].mean())
df["distance"]
df.isna().sum()

# %%
import matplotlib.pyplot as plt

# %%
sns.lineplot(x=df.index,y=df["number"],data=df)
plt.show()

# %%
sns.lineplot(x=df.index,y=df["orbital_period"],data=df)
plt.show()

# %%
sns.lineplot(x=df.index,y=df["distance"],data=df)
plt.show()

# %%
sns.scatterplot(x=df["year"],y=df["distance"],data=df,hue='year',color='green')
plt.show()

# %%
sns.scatterplot(x=df["number"],y=df["mass"],data=df,hue='year')
plt.show()

# %%
sns.barplot(x=df.index,y=df["method"],data=df)
plt.show()

# %%
sns.histplot(df["number"],kde=True)
plt.show()

# %%
sns.histplot(df["mass"],kde=True)
plt.show()

# %%
sns.histplot(df["orbital_period"],kde=True)
plt.show()

# %%
sns.histplot(df["year"],kde=True,fill=True)
plt.show()

# %%
df

# %%
cor = df.drop(columns='method')
cor

# %%
cor=cor.corr()
cor

# %%
sns.heatmap(cor,annot=True,cmap='coolwarm')

# %%
sns.boxplot(x='number',y='mass',data=df)

# %%
sns.boxplot(x='number',y='distance',data=df)

# %%
sns.boxplot(x='number',y='year',data=df)

# %%
sns.boxplot(x='number',y='mass',data=df)

# %%
sns.boxplot(x='year',y='mass',data=df)

# %%
sns.violinplot(y='mass', x='number', data=df)

# %%
df

# %%
sns.violinplot(y='distance', x='number', data=df)

# %%
sns.pairplot(df)

# %%
sns.catplot(df['mass'])

# %%
sns.catplot(df['number'])

# %%
sns.catplot(df['mass'])
