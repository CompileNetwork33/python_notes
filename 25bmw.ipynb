# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df  = pd.read_csv(r"C:\Users\kashi\OneDrive\图片\Desktop\techcadd\bmw_global_sales_dataset.csv")
df.head()
# Out:
#    year  month    country     model   segment engine_type  price_usd  \
# 0  2021      1  Australia        X1       SUV      Petrol      82234
# 1  2018      8  Australia        i4     Sedan    Electric      82291
# 2  2022     12        USA  5 Series  Electric      Hybrid      40594
# 3  2019     11  Australia        i7       SUV    Electric      42371
# 4  2021     12     Brazil        X5       SUV      Diesel      82315
#
#    marketing_spend_usd  dealership_count  fuel_price_usd  gdp_growth_percent  \
# 0               315372                96            0.97                6.29
# 1               447798               234            0.97                6.29
# 2               259755                25            0.97                6.29
# 3               323541               319            0.97                6.29
# 4               482015               367            0.97                6.29
#
#    interest_rate_percent  competition_index  units_sold
# ...

# %%
df.isna().sum()
# Out:
# year                     0
# month                    0
# country                  0
# model                    0
# segment                  0
# engine_type              0
# price_usd                0
# marketing_spend_usd      0
# dealership_count         0
# fuel_price_usd           0
# gdp_growth_percent       0
# interest_rate_percent    0
# competition_index        0
# units_sold               0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['country'] = le.fit_transform(df['country'])
df['country'] = le.fit_transform(df['country'])
df['model'] = le.fit_transform(df['model'])
df['segment'] = le.fit_transform(df['segment'])
df['engine_type'] = le.fit_transform(df['engine_type'])
df.head()
# Out:
#    year  month  country  model  segment  engine_type  price_usd  \
# 0  2021      1        0      3        1            3      82234
# 1  2018      8        0      7        2            1      82291
# 2  2022     12        9      1        0            2      40594
# 3  2019     11        0      8        1            1      42371
# 4  2021     12        1      5        1            0      82315
#
#    marketing_spend_usd  dealership_count  fuel_price_usd  gdp_growth_percent  \
# 0               315372                96            0.97                6.29
# 1               447798               234            0.97                6.29
# 2               259755                25            0.97                6.29
# 3               323541               319            0.97                6.29
# 4               482015               367            0.97                6.29
#
#    interest_rate_percent  competition_index  units_sold
# 0                    1.2                  8         324
# ...

# %%
x =df[['year','month','country','model','segment','engine_type','price_usd','marketing_spend_usd','dealership_count','fuel_price_usd']]
x.head()
# Out:
#    year  month  country  model  segment  engine_type  price_usd  \
# 0  2021      1        0      3        1            3      82234
# 1  2018      8        0      7        2            1      82291
# 2  2022     12        9      1        0            2      40594
# 3  2019     11        0      8        1            1      42371
# 4  2021     12        1      5        1            0      82315
#
#    marketing_spend_usd  dealership_count  fuel_price_usd
# 0               315372                96            0.97
# 1               447798               234            0.97
# 2               259755                25            0.97
# 3               323541               319            0.97
# 4               482015               367            0.97

# %%
y =df['price_usd']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2)

# %%
x.dtypes
# Out:
# year                     int64
# month                    int64
# country                  int64
# model                    int64
# segment                  int64
# engine_type              int64
# price_usd                int64
# marketing_spend_usd      int64
# dealership_count         int64
# fuel_price_usd         float64
# dtype: object

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction=lr.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,prediction)*100
# Out:
# 100.0

# %% [markdown]
# ### polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures
pf = PolynomialFeatures(degree=3)
pf_poly = pf.fit_transform(x)
pf
# Out:
# PolynomialFeatures(degree=3)

# %%
pre = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(pre,y_test)
# Out:
# 1.0

# %% [markdown]
# ### decision tree

# %%
df.nunique()
# Out:
# year                      10
# month                     12
# country                   10
# model                     10
# segment                    3
# engine_type                4
# price_usd                994
# marketing_spend_usd      996
# dealership_count         355
# fuel_price_usd             1
# gdp_growth_percent         1
# interest_rate_percent      1
# competition_index         10
# units_sold               621
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8)

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor(max_depth=5,random_state=42)

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, random_state=42)

# %%
pre = dt.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,pre)
# Out:
# 0.9989461905466122

# %% [markdown]
# ## Random forest

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(max_depth=10,n_estimators=10)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=10)

# %%
prediction = rf.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,prediction)*100
# Out:
# 99.99723640669401

# %%
df.columns
# Out:
# Index(['year', 'month', 'country', 'model', 'segment', 'engine_type',
#        'price_usd', 'marketing_spend_usd', 'dealership_count',
#        'fuel_price_usd', 'gdp_growth_percent', 'interest_rate_percent',
#        'competition_index', 'units_sold'],
#       dtype='object')

# %%
plt.plot(df['units_sold'],color='pink',linestyle='-',linewidth=4,marker='X',markersize=10)
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('unit sold')
plt.grid('True')

# %%
x = ['LR','PR','DR','RF']
y = [100,100,99,99]
plt.bar(x,y)
plt.show
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\kashi\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python312\\site-packages\\matplotlib\\pyplot.py'>
