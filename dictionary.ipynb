# %%
#Write a program to create a dictionary with at least five key–value pairs and display it.
a = {}
a
# Out:
# {}

# %%
a = {'name':'vaishnavi', 'age':20,'course':'AI/ML'}
a
# Out:
# {'name': 'vaishnavi', 'age': 20, 'course': 'AI/ML'}

# %%
#Write a program to create a dictionary containing keys of different data types.
b = {'name':'nancy','roll no':20,'cgpa':9.0,'course':'AI/ML','PAN CARD': True}
b
# Out:
# {'name': 'nancy',
#  'roll no': 20,
#  'cgpa': 9.0,
#  'course': 'AI/ML',
#  'PAN CARD': True}

# %%
#Write a program to access the value of a specific key in a dictionary.
b = {'name':'nancy','roll no':20,'cgpa':9.0,'course':'AI/ML','PAN CARD': True}
b
b['name']
# Out:
# 'nancy'

# %%
#Write a program to add a new key–value pair to an existing dictionary.#
b['city'] = {"delhi"}
b
# Out:
# {'name': 'nancy',
#  'roll no': 20,
#  'cgpa': 9.0,
#  'course': 'AI/ML',
#  'PAN CARD': True,
#  'city': {'delhi'}}

# %%
#Write a program to add a new key–value pair to an existing dictionary.
#Write a program to update the value of an existing key in a dictionary.
b['city'] = {"lucknow"}
b
# Out:
# {'name': 'nancy',
#  'roll no': 20,
#  'cgpa': 9.0,
#  'course': 'AI/ML',
#  'PAN CARD': True,
#  'city': {'lucknow'}}

# %%
#Write a program to delete a specific key–value pair from a dictionary using the del statement.
b = {'name':'nancy','roll no':20,'cgpa':9.0,'course':'AI/ML','PAN CARD': True}
b
del b ['cgpa']
b
# Out:
# {'name': 'nancy', 'roll no': 20, 'course': 'AI/ML', 'PAN CARD': True}

# %%
#Write a program to remove a key–value pair using the pop() method
b.pop('name')
b
# Out:
# {'roll no': 20, 'course': 'AI/ML', 'PAN CARD': True}

# %%
#Write a program to remove and return the last inserted key–value pair using the popitem() method.
b.popitem()
b
# Out:
# {'roll no': 20, 'course': 'AI/ML'}

# %%
#Write a program to clear all elements from a dictionary using the clear() method.
b.clear()
b
# Out:
# {}

# %%
#Write a program to create a copy of a dictionary using the copy() method.
a = b.copy()
a
# Out:
# {'roll no': 20, 'course': 'AI/ML'}

# %%
#Write a program to find the total number of key–value pairs in a dictionary using the len() function
b = {'name':'nancy','roll no':20,'cgpa':9.0,'course':'AI/ML','PAN CARD': True}
b
len(b)
# Out:
# 5

# %%
#Write a program to retrieve all keys from a dictionary using the keys() method
b = {'name':'nancy','roll no':20,'cgpa':9.0,'course':'AI/ML','PAN CARD': True}
b
b.keys()
# Out:
# dict_keys(['name', 'roll no', 'cgpa', 'course', 'PAN CARD'])

# %%
b = {'name':'nancy','roll no':20,'cgpa':9.0,'course':'AI/ML','PAN CARD': True}
b
b.values()
# Out:
# dict_values(['nancy', 20, 9.0, 'AI/ML', True])

# %%
#Write a program to retrieve all key–value pairs using the items() method.
b = {'name':'nancy','roll no':20,'cgpa':9.0,'course':'AI/ML','PAN CARD': True}
b
b.items()
# Out:
# dict_items([('name', 'nancy'), ('roll no', 20), ('cgpa', 9.0), ('course', 'AI/ML'), ('PAN CARD', True)])

# %%
#Write a program to check whether a specific key exists in a dictionary.
b = {'name':'nancy','roll no':20,'cgpa':9.0,'course':'AI/ML','PAN CARD': True}
b
if({'name':'nancy'}):
    print("yes, it is exist")
else:
    print("not exist")
# Out:
# yes, it is exist

# %%
#Write a program to update multiple key–value pairs in a dictionary using the update() method.
b = {'name':'nancy','roll no':20,'cgpa':9.0,'course':'AI/ML','PAN CARD': True}
b
b['country'] = {'India'}
b.update()
b
# Out:
# {'name': 'nancy',
#  'roll no': 20,
#  'cgpa': 9.0,
#  'course': 'AI/ML',
#  'PAN CARD': True,
#  'country': {'India'}}

# %%
c = dict({'name':'diya','class':10,'roll no': 45,'state':'punjab'})
c
# Out:
# {'name': 'diya', 'class': 10, 'roll no': 45, 'state': 'punjab'}

# %%
#Write a program to create a dictionary from two lists using the zip() function.
keys = {'name','age','rollno'}
values = {'vaishnavi',30,33}
c = dict(zip(keys,values))
c
# Out:
# {'name': 33, 'rollno': 'vaishnavi', 'age': 30}

# %%
#Write a program to access dictionary values using the get() method.
b.get('name')
# Out:
# 'nancy'

# %%
#Write a program to set a default value for a key using the setdefault() method.
b.setdefault(44)
b
# Out:
# {'name': 'nancy',
#  'roll no': 20,
#  'cgpa': 9.0,
#  'course': 'AI/ML',
#  'PAN CARD': True,
#  'country': {'India'},
#  44: None}
