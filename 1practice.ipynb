# %%
temp = 20

if(temp<15):
    print("warm")
elif(temp>=15 & temp<=25):
    print("inclusive")
else:
    print("Hot")
# Out:
# inclusive

# %%
n = int(input("Enter a number"))
if(n > 0):
    print("Number is positive")
elif(n < 0):
        print("number is neative")
elif(n == 0):
      print("Equal to zero")
else:
      print("result")
# Out:
# Number is positive

# %%
a = int(input("Enter a number a "))
b = int(input("Enter a number b "))
if (a > b):
    print("a is greater")
elif(b > a):
    print("b is greater")
elif(a==b):
    print("both are same")
else:
    print("null")
# Out:
# a is greater

# %%
m = input("enter a valid password")
if(m=='admin123'):
    print("Access granted")
else:
    print("Access not granted")
# Out:
# Access not granted

# %%
x = int(input("Enter a number x"))
y = int(input("Enter a number y"))
z = int(input("Enter a number z"))
if(x > y or x > z):
    print("x is greater ")
elif(y>x or y>z):
    print("y is greater")
elif(z>y or z>x):
    print("z is greater")
else:
    print("null")
# Out:
# x is greater

# %%
marks = int(input("enter a number"))
atten = 'attendence'
if (marks>40 or atten>=75):
    print("pass")
else:
    print("fail")
# Out:
# pass

# %%
var = input("enter a variable")
if(var =='a','i','o','u','e'):
    print("vowel word")
elif(var=='@','&','$','#','*'):
    print("Special character")
elif var.isdigit():
    print("digit")
else:
    print("consonent")
# Out:
# vowel word

# %%
age = int(input("Enter a age:"))
if age == 0:
    if age == 14:
         print("child")
    elif age == 13 or 19:
        print("Teen")
    elif age == 20 or 59:
            print("adult")
else:
    print("senior")
# Out:
# senior

# %%
data = []
if not data:
    print("empty") 
elif len(data) == 1:
    print("one item ")
else:
    print("multiple item")
# Out:
# empty

# %%
a = int(input("enter side of a"))
b = int(input("enter side of b"))
c = int(input("enter side of c"))
if a==b==c:
    print("Equalateral triangle")
elif a==b or b==c or c!=a :
    print("Isoceles triangle")
else:
    print("Scalen triangle")
# Out:
# Isoceles triangle

# %%
x = int(input("enter a number:"))
if x % 4 == 0 and x % 100 != 0:
    print("leap year")
else:
    print("not leap year")
# Out:
# leap year

# %%
list1=[1,1,3,2,3,4,'hello',5.0,True]
print(list1)
list1.append([400,500])
print(list1)
list1.insert(4,44)
print(list1)
list1.extend([100,200,300])
print(list1)
list1.pop(3)
print(list1)
list1.remove(5.0)
print(list1)
list1.clear()
print(list1)
# Out:
# [1, 1, 3, 2, 3, 4, 'hello', 5.0, True]
# [1, 1, 3, 2, 3, 4, 'hello', 5.0, True, [400, 500]]
# [1, 1, 3, 2, 44, 3, 4, 'hello', 5.0, True, [400, 500]]
# [1, 1, 3, 2, 44, 3, 4, 'hello', 5.0, True, [400, 500], 100, 200, 300]
# [1, 1, 3, 44, 3, 4, 'hello', 5.0, True, [400, 500], 100, 200, 300]
# [1, 1, 3, 44, 3, 4, 'hello', True, [400, 500], 100, 200, 300]
# []

# %%
name = "vaishnavi"
print(f"my name is :{name}")
# Out:
# my name is :vaishnavi
