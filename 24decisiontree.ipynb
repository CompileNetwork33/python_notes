# %%
import pandas as pd

# %%
dt= pd.read_csv(r"C:\Users\kashi\OneDrive\图片\Desktop\techcadd\student peforrmencev datadet.zip")
dt.head()
# Out:
#    study_hours  attendance  sleep_hours  internet_usage  \
# 0            7          56            8               7
# 1            4          69            5               3
# 2           11          60            7               6
# 3            8          99            9               8
# 4            5          52            8               6
#
#    assignments_completed  previous_score  exam_score placement_status
# 0                     10              62      100.00           Placed
# 1                      8              56      100.00           Placed
# 2                     10              45      100.00           Placed
# 3                      4              55       90.17           Placed
# 4                      8              40       78.82           Placed

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
dt['placement_status']=le.fit_transform(dt['placement_status'])
dt
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score  placement_status
# 0                        10              62      100.00                 1
# 1                         8              56      100.00                 1
# ...

# %%
x=dt.drop(columns=['placement_status'])
x
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score
# 0                        10              62      100.00
# 1                         8              56      100.00
# 2                        10              45      100.00
# ...

# %%
y=dt['placement_status']
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 9995    0
# 9996    1
# 9997    1
# 9998    1
# 9999    1
# Name: placement_status, Length: 10000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.75,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor(max_depth=2)

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(max_depth=5,n_estimators=10)

# %%
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
prediction=dtr.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,prediction)*100
# Out:
# 100.0
