# %%
import pandas as pd
list = [2,'NANCY',9.0,True]
m = pd.Series(list,index=['a','b','c','d'])
m
type(m)
# Out:
# pandas.core.series.Series

# %%
m['a']=5
m
m.head(2)
m.tail(3)
# Out:
# b    NANCY
# c      9.0
# d     True
# dtype: object

# %%
m.sample(2)
# Out:
# b    NANCY
# c      9.0
# dtype: object

# %%
list2 = [3,6,8,3.5,7,0,22.5,66.8,77.9]
k = pd.Series(list2,name="Numbers")
k.dtype
# Out:
# dtype('float64')

# %%
k=k.astype(int)

# %%
k
# Out:
# 0     3
# 1     6
# 2     8
# 3     3
# 4     7
# 5     0
# 6    22
# 7    66
# 8    77
# Name: Numbers, dtype: int64

# %%
k.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 9 entries, 0 to 8
# Series name: Numbers
# Non-Null Count  Dtype
# --------------  -----
# 9 non-null      int64
# dtypes: int64(1)
# memory usage: 204.0 bytes

# %%
k.isna().sum()
# Out:
# np.int64(0)

# %%
k.sum()
# Out:
# np.int64(192)

# %%
k.mean()
# Out:
# np.float64(21.333333333333332)

# %%
k.median()
# Out:
# 7.0

# %%
k.std()
# Out:
# 29.24038303442689

# %%
k.var()
# Out:
# 855.0

# %%
k.mode()
# Out:
# 0    3
# Name: Numbers, dtype: int64

# %%
k.describe()
# Out:
# count     9.000000
# mean     21.333333
# std      29.240383
# min       0.000000
# 25%       3.000000
# 50%       7.000000
# 75%      22.000000
# max      77.000000
# Name: Numbers, dtype: float64

# %%
k.shape
# Out:
# (9,)

# %%
k.drop_duplicates()
# Out:
# 0     3
# 1     6
# 2     8
# 4     7
# 5     0
# 6    22
# 7    66
# 8    77
# Name: Numbers, dtype: int64

# %%
k.drop([0], inplace=True)

# %%
k
# Out:
# 1     6
# 2     8
# 3     3
# 4     7
# 5     0
# 6    22
# 7    66
# 8    77
# Name: Numbers, dtype: int64
