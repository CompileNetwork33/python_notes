# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\kashi\OneDrive\图片\Desktop\techcadd\Details.csv")
df.head(4)
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-25681    1096     658         7  Electronics  Electronic Games
# 1  B-26055    5729      64        14    Furniture            Chairs
# 2  B-25955    2927     146         8    Furniture         Bookcases
# 3  B-26093    2847     712         8  Electronics          Printers
#
#    PaymentMode
# 0          COD
# 1          EMI
# 2          EMI
# 3  Credit Card

# %%
df.shape
# Out:
# (1500, 7)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0     B-25681    1096     658         7  Electronics  Electronic Games
# 1     B-26055    5729      64        14    Furniture            Chairs
# 2     B-25955    2927     146         8    Furniture         Bookcases
# 3     B-26093    2847     712         8  Electronics          Printers
# 4     B-25602    2617    1151         4  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-25700       7      -3         2     Clothing       Hankerchief
# 1496  B-25757    3151     -35         7     Clothing          Trousers
# 1497  B-25973    4141    1698        13  Electronics          Printers
# 1498  B-25698       7      -2         1     Clothing       Hankerchief
# 1499  B-25993    4363     305         5    Furniture            Tables
#
#       PaymentMode
# 0             COD
# 1             EMI
# 2             EMI
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0     B-25681    1096     658         7  Electronics  Electronic Games
# 1     B-26055    5729      64        14    Furniture            Chairs
# 2     B-25955    2927     146         8    Furniture         Bookcases
# 3     B-26093    2847     712         8  Electronics          Printers
# 4     B-25602    2617    1151         4  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-25700       7      -3         2     Clothing       Hankerchief
# 1496  B-25757    3151     -35         7     Clothing          Trousers
# 1497  B-25973    4141    1698        13  Electronics          Printers
# 1498  B-25698       7      -2         1     Clothing       Hankerchief
# 1499  B-25993    4363     305         5    Furniture            Tables
#
#       PaymentMode
# 0             COD
# 1             EMI
# 2             EMI
# ...

# %%
df.columns
# Out:
# Index(['Order ID', 'Amount', 'Profit', 'Quantity', 'Category', 'Sub-Category',
#        'PaymentMode'],
#       dtype='object')

# %%
df.ndim
# Out:
# 2

# %%
df.sample(5)# random values
# Out:
#      Order ID  Amount  Profit  Quantity     Category Sub-Category  PaymentMode
# 1224  B-25951      40      18         1  Electronics  Accessories  Credit Card
# 418   B-25858     294     109         7  Electronics  Accessories          EMI
# 675   B-25834      16       5         1     Clothing        Stole          UPI
# 306   B-25903      37      17         3     Clothing  Hankerchief   Debit Card
# 456   B-25823      59       6         1  Electronics  Accessories          UPI

# %%
df.dtypes
# Out:
# Order ID        object
# Amount           int64
# Profit           int64
# Quantity         int64
# Category        object
# Sub-Category    object
# PaymentMode     object
# dtype: object

# %%
df.isna().sum()
# Out:
# Order ID        0
# Amount          0
# Profit          0
# Quantity        0
# Category        0
# Sub-Category    0
# PaymentMode     0
# dtype: int64

# %%
df['Amount'].mean()
# Out:
# np.float64(291.8473333333333)

# %%
df['Amount'].median()
# Out:
# 122.0

# %%
df['Amount'].mode()
# Out:
# 0    27
# 1    44
# Name: Amount, dtype: int64

# %%
df['Amount'].corr
df['Amount'].var
# Out:
# <bound method Series.var of 0       1096
# 1       5729
# 2       2927
# 3       2847
# 4       2617
#         ...
# 1495       7
# 1496    3151
# 1497    4141
# 1498       7
# 1499    4363
# Name: Amount, Length: 1500, dtype: int64>

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0     B-25681    1096     658         7  Electronics  Electronic Games
# 1     B-26055    5729      64        14    Furniture            Chairs
# 2     B-25955    2927     146         8    Furniture         Bookcases
# 3     B-26093    2847     712         8  Electronics          Printers
# 4     B-25602    2617    1151         4  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-25700       7      -3         2     Clothing       Hankerchief
# 1496  B-25757    3151     -35         7     Clothing          Trousers
# 1497  B-25973    4141    1698        13  Electronics          Printers
# 1498  B-25698       7      -2         1     Clothing       Hankerchief
# 1499  B-25993    4363     305         5    Furniture            Tables
#
#       PaymentMode
# 0             COD
# 1             EMI
# 2             EMI
# 3     Credit Card
# ...

# %%
df.shape
# Out:
# (1500, 7)

# %%
df.reset_index(drop=True)
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0     B-25681    1096     658         7  Electronics  Electronic Games
# 1     B-26055    5729      64        14    Furniture            Chairs
# 2     B-25955    2927     146         8    Furniture         Bookcases
# 3     B-26093    2847     712         8  Electronics          Printers
# 4     B-25602    2617    1151         4  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-25700       7      -3         2     Clothing       Hankerchief
# 1496  B-25757    3151     -35         7     Clothing          Trousers
# 1497  B-25973    4141    1698        13  Electronics          Printers
# 1498  B-25698       7      -2         1     Clothing       Hankerchief
# 1499  B-25993    4363     305         5    Furniture            Tables
#
#       PaymentMode
# 0             COD
# 1             EMI
# 2             EMI
# 3     Credit Card
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["Amount"],color='red',linestyle='-.',marker='X',linewidth=2,markersize=15)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title("Line Plot")
plt.grid(True)
plt.show()

# %%
plt.plot(df["Profit"],color='red',linestyle='-.',marker='X',linewidth=2,markersize=15)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title("Line Plot")
plt.grid(True)
plt.show()

# %%
plt.plot(df["Quantity"],color='red',linestyle='-.',marker='X',linewidth=2,markersize=15)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title("Line Plot")
plt.grid(True)
plt.show()
