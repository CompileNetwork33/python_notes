# %% [markdown]
# ### Tuple
# 1. immutable
# 2. orderd
# 3.

# %%
l1 = []
print(l1)
l2 = list()
l2
# Out:
# []
# []

# %%
tup = ()
tuppu = ()
tup
tuppu
# Out:
# ()

# %%
nums = (1,4,8,2,0,97,5,2)
nums
nums2 = list(nums)
nums2.insert(2,22)
nums2
# Out:
# [1, 4, 22, 8, 2, 0, 97, 5, 2]

# %% [markdown]
# ### set
# #### Festures
# 1. no repetive value
# 2. represents with curly braces
# 3. no order

# %%
set = {}
set
# Out:
# {}

# %%
names = {"nancy","reeta",3.5,7}
names
names.add("vaishnavi")
names
names.remove(7)
names
# Out:
# {3.5, 'nancy', 'reeta', 'vaishnavi'}
