# %%
#Q1. Create a Pandas Series using a Python list containing values [10, 20, 30, 40, 50].
#After creating the Series, display the values, index labels, and datatype of the Series.
import pandas as pd
nums = [2,6,4,3,6,7,8]
num= pd.Series(nums)
num

# %%
num.index
num.dtype

# %%
#Q2. Create a Pandas Series with values [5, 10, 15] and custom index labels ['a','b','c'].
#Access and print the value stored at index label 'b'.
values  = [5, 10, 15]
n = pd.Series((values),index=['a','b','c'])
n
n['b']

# %%
#Convert the dictionary {'Math':90, 'Physics':85, 'Chemistry':88} into a Pandas
#Series. Display subject names as index.
test ={'Math':90, 'Physics':85, 'Chemistry':88}
k = pd.Series(test)
k

# %%
#Q4. Create a DataFrame from dictionary containing columns Name, Age and Marks forat least 4 students. Display the complete DataFrame.
data = {'name':['nancy','radha','rimjhim','nisha'],'age':[55,33,23,45],'marks':[88,99,98,89]}
df=pd.DataFrame(data)
df

# %%
#Q5. Create a DataFrame using a list of lists representing Product Name, Price and Quantity columns.
data = [['namkeen',33,3],
['nuts',20,9],
['milk',21,10]]
df = pd.DataFrame(data,columns=['product name','price','quantity'])
df

# %%
#Q6. Using NumPy random module, generate a 5×3 array of random numbers and convert it into a Pandas DataFrame with suitable column names.
#import random
import numpy as np
m = np.random.rand(2,3)
df= pd.DataFrame(m,columns=['col1','col2','col3'])
df

# %%
#Q7. On any created DataFrame, use head(), tail(), info(), and describe() functions and observe the output of each function
data = {'name':['nancy','radha','rimjhim','nisha'],'age':[55,33,23,45],'marks':[88,99,98,89]}
df=pd.DataFrame(data)
df.head(2)
df.tail(2)
df.info()
df.describe()

# %%
#Q8.Find and print the shape of the DataFrame, list of column names and index range.
data = {'name':['nancy','radha','rimjhim','nisha'],'age':[55,33,23,45],'marks':[88,99,98,89]}
df=pd.DataFrame(data)
df.shape
df.columns
df.index

# %%
#Q9.Demonstrate column selection by extracting a single column as Series and multiple columns as a new DataFrame

# %%
#Q10. Perform row selection using both iloc (position■based indexing) and loc(label■based indexing).
data = {
    'name':['nancy','vaishnavi','lado','nikki','radhe'],
    'age':[22,33,12,21,15],
    'marks':[90,93,92,91,90]
}
df = pd.DataFrame(data)
df

# %%
#df.iloc[0,1:]
df.loc[2,'marks']

# %%
#Q11. Apply conditional filtering to display only those rows where Marks are greater than 70.
m = df['marks']>90
m

# %%
#Q12. Create a new column named Total by adding 5 bonus marks to the Marks column.
df['total'] = df['marks']+5
df

# %%
#Q13. Delete any one column from the DataFrame using appropriate Pandas method
p= df.drop(columns='marks')
p

# %%
#Q14. Rename one or more column names using rename() function.
p = df.rename(columns={'total':'totally'})
p

# %%
# Sort the DataFrame first by Marks in ascending order and then by Age in descending order.
l=df.sort_values(by='age')
q = df.sort_values(by='marks',ascending=False)
l
q

# %%
#Q16. Manually create a DataFrame that contains some missing (NaN) values in numeric columns
data = {
    'name':['nancy','vaishnavi','lado','nikki','radhe'],
    'age':[22,np.nan,12,21,15],
    'marks':[90,np.nan,92,91,90]
}
df = pd.DataFrame(data)
df

# %%
#Q17. Detect missing values using isnull() or isna() and count total missing values
df.isnull().sum

# %%
df.isna()

# %%
# Q18. Fill missing numeric values using mean of that column and also demonstrate forward fill method.
m = df.fillna(0)
m

# %%
#Remove rows that contain missing values using dropna().
df.dropna()

# %%
#Q20. Calculate statistical measures such as mean, median, standard deviation,variance and correlation between numeric columns.
df['age'].mean()
df['age'].median()
df['age'].std()
df['age'].var()
df['age'].corr

# %%
#Q21. Create a DataFrame containing Department and Salary columns for multiple employees. Group the data department■wise and compute average salary.
import pandas as pd
company = [
['radha','nancy','kishori','naina','rudra'],
['cse','AI/ML','Ds','civil','cse'],
[45000,50000,30000,35000,40000]] 
d = pd.DataFrame(company,columns=['Emp_name','department','salary'])
d
