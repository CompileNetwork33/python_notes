# %%
x = 10
type(x)

# %%
a = 2.4
type(a)

# %%
a = 10
b = 20
print(a+b)#arithematic  opertaion

# %%
a = 40
b = 50
print(b>a)#comparision

# %%
print(a==b)

# %%
x = 9
x+=3
print(x)#assignment operator

# %%
print(a>b  and b>a)

# %%
print(not(a>b))#logical operator

# %%
a = 6

# %%
##type casting
x = 110
float(x)

# %%
age=int(input())

# %%
a = 19
b = 23
temp = a
a = b
b = temp
print(temp,a,b)
# Out:
# 19 23 19
