# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\kashi\OneDrive\图片\Desktop\techcadd\archive (8).zip")
df.head(4)
# Out:
#     ID  Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0  100   Customer_100  ORD-41285  11/22/2024        Blender         Home
# 1  101   Customer_101  ORD-35783    7/5/2025     Smartphone  Electronics
# 2  102   Customer_102  ORD-84355  12/23/2024  Tennis Racket       Sports
# 3  103   Customer_103  ORD-57811   3/19/2025        Science        Books
#
#   Quantity   Price    Payment_Method      Status    Total
# 0        3      38  Cash on Delivery     Shipped   114.00
# 1        2     abd            PayPal  Processing      NaN
# 2        1  389.05            PayPal   Delivered   389.05
# 3        5  233.92            PayPal  Processing  1169.60

# %%
df.shape
# Out:
# (103, 11)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       ID  Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100   Customer_100  ORD-41285  11/22/2024        Blender         Home
# 1    101   Customer_101  ORD-35783    7/5/2025     Smartphone  Electronics
# 2    102   Customer_102  ORD-84355  12/23/2024  Tennis Racket       Sports
# 3    103   Customer_103  ORD-57811   3/19/2025        Science        Books
# 4    104   Customer_104  ORD-93614  10/20/2025      Biography        Books
# ..   ...            ...        ...         ...            ...          ...
# 98   198   Customer_198  ORD-14608   7/27/2025         Vacuum          NaN
# 99   199   Customer_199  ORD-82922   1/22/2025        Blender         Home
# 100  175   Customer_175  ORD-56651   2/24/2025     Headphones  Electronics
# 101  142   Customer_142  ORD-69018  10/30/2025          Shoes     Clothing
# 102  146   Customer_146  ORD-32755    7/9/2025     Basketball   electronic
#
# ...

# %%
df.info
df
# Out:
#       ID  Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100   Customer_100  ORD-41285  11/22/2024        Blender         Home
# 1    101   Customer_101  ORD-35783    7/5/2025     Smartphone  Electronics
# 2    102   Customer_102  ORD-84355  12/23/2024  Tennis Racket       Sports
# 3    103   Customer_103  ORD-57811   3/19/2025        Science        Books
# 4    104   Customer_104  ORD-93614  10/20/2025      Biography        Books
# ..   ...            ...        ...         ...            ...          ...
# 98   198   Customer_198  ORD-14608   7/27/2025         Vacuum          NaN
# 99   199   Customer_199  ORD-82922   1/22/2025        Blender         Home
# 100  175   Customer_175  ORD-56651   2/24/2025     Headphones  Electronics
# 101  142   Customer_142  ORD-69018  10/30/2025          Shoes     Clothing
# 102  146   Customer_146  ORD-32755    7/9/2025     Basketball   electronic
#
#     Quantity   Price    Payment_Method      Status     Total
# ...

# %%
df.columns
# Out:
# Index(['ID', ' Customer_Name', 'Order_ID', 'Order_Date', 'Product',
#        ' Category', 'Quantity', 'Price', 'Payment_Method', 'Status', 'Total'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ID                 0
#  Customer_Name     0
# Order_ID           0
# Order_Date         0
# Product            0
#  Category          8
# Quantity           5
# Price              5
# Payment_Method     0
# Status             0
# Total             14
# dtype: int64

# %%
df.isna().sum()
# Out:
# ID                 0
#  Customer_Name     0
# Order_ID           0
# Order_Date         0
# Product            0
#  Category          8
# Quantity           5
# Price              5
# Payment_Method     0
# Status             0
# Total             14
# dtype: int64

# %%
df['Price']=df['Price'].fillna(df['Price'].mode()[0])
df.isnull().sum()
df[df["Price"]=='abd']
df.drop([1],inplace=True)
df.drop([96],inplace=True)

# %%
df
# Out:
#       ID  Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100   Customer_100  ORD-41285  11/22/2024        Blender         Home
# 2    102   Customer_102  ORD-84355  12/23/2024  Tennis Racket       Sports
# 3    103   Customer_103  ORD-57811   3/19/2025        Science        Books
# 4    104   Customer_104  ORD-93614  10/20/2025      Biography        Books
# 5    105   Customer_105  ORD-22442  11/20/2024  Tennis Racket       Sports
# ..   ...            ...        ...         ...            ...          ...
# 98   198   Customer_198  ORD-14608   7/27/2025         Vacuum          NaN
# 99   199   Customer_199  ORD-82922   1/22/2025        Blender         Home
# 100  175   Customer_175  ORD-56651   2/24/2025     Headphones  Electronics
# 101  142   Customer_142  ORD-69018  10/30/2025          Shoes     Clothing
# 102  146   Customer_146  ORD-32755    7/9/2025     Basketball   electronic
#
#     Quantity   Price    Payment_Method      Status     Total
# ...

# %%
df.dtypes
df
# Out:
#       ID  Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100   Customer_100  ORD-41285  11/22/2024        Blender         Home
# 2    102   Customer_102  ORD-84355  12/23/2024  Tennis Racket       Sports
# 3    103   Customer_103  ORD-57811   3/19/2025        Science        Books
# 4    104   Customer_104  ORD-93614  10/20/2025      Biography        Books
# 5    105   Customer_105  ORD-22442  11/20/2024  Tennis Racket       Sports
# ..   ...            ...        ...         ...            ...          ...
# 98   198   Customer_198  ORD-14608   7/27/2025         Vacuum          NaN
# 99   199   Customer_199  ORD-82922   1/22/2025        Blender         Home
# 100  175   Customer_175  ORD-56651   2/24/2025     Headphones  Electronics
# 101  142   Customer_142  ORD-69018  10/30/2025          Shoes     Clothing
# 102  146   Customer_146  ORD-32755    7/9/2025     Basketball   electronic
#
#     Quantity   Price    Payment_Method      Status     Total
# ...

# %%
df["Price"].dtype
df["Price"].apply(type).value_counts()
# Out:
# Price
# <class 'str'>    101
# Name: count, dtype: int64

# %%
df["Price"]=pd.to_numeric(df["Price"],errors='coerce')
df["Price"].dtype
# Out:
# dtype('float64')

# %%
df['Category'].isnull(df['Category'].mode()[0],inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\kashi\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ...

# %%
t= pd.to_datetime(df['Order_Date'],errors='coerce')
t

# %%
y=df.sort_values('Price',ascending=False)
y

# %%
def discount(x):
    if x >= 300:
        print("expensive")
    else:
        print("cheap")

# %%
df['discount'] = df['Price'].apply(discount)

# %%
df["Quantity"]=pd.to_numeric(df["Quantity"],errors='coerce')
df["Quantity"].dtype

# %%
(df["Quantity"]<0).sum()

# %%
df["Quantity"] = df["Quantity"].abs()#changing
df

# %%
df["Category"].dtype

# %%
df.groupby("Category")["Price"].mean()

# %%
df.columns
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#       ID  Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100   Customer_100  ORD-41285  11/22/2024        Blender         Home
# 2    102   Customer_102  ORD-84355  12/23/2024  Tennis Racket       Sports
# 3    103   Customer_103  ORD-57811   3/19/2025        Science        Books
# 4    104   Customer_104  ORD-93614  10/20/2025      Biography        Books
# 5    105   Customer_105  ORD-22442  11/20/2024  Tennis Racket       Sports
# ..   ...            ...        ...         ...            ...          ...
# 98   198   Customer_198  ORD-14608   7/27/2025         Vacuum          NaN
# 99   199   Customer_199  ORD-82922   1/22/2025        Blender         Home
# 100  175   Customer_175  ORD-56651   2/24/2025     Headphones  Electronics
# 101  142   Customer_142  ORD-69018  10/30/2025          Shoes     Clothing
# 102  146   Customer_146  ORD-32755    7/9/2025     Basketball   electronic
#
#     Quantity   Price    Payment_Method      Status     Total
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df["Total"], bins=20,color='green')
plt.title("Distribution of App Ratings")
plt.xlabel("Quantity")
plt.ylabel("Frequency")
plt.show()

# %%
plt.pie(df["Payment_Method"].value_counts(),autopct="%1.1f%%")
plt.show()

# %%
plt.pie(df["Status"].value_counts(),autopct="%1.1f%%")
plt.show()
