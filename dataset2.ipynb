# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\kashi\OneDrive\图片\Desktop\techcadd\archive (8).zip")
df.head(4)

# %%
df.shape

# %%
df.describe

# %%
df.info
df

# %%
df.columns

# %%
df.isnull().sum()

# %%
df.isna().sum()

# %%
df['Price']=df['Price'].fillna(df['Price'].mode()[0])
df.isnull().sum()
df[df["Price"]=='abd']
df.drop([1],inplace=True)
df.drop([96],inplace=True)

# %%
df

# %%
df.dtypes
df

# %%
df["Price"].dtype
df["Price"].apply(type).value_counts()

# %%
df["Price"]=pd.to_numeric(df["Price"],errors='coerce')
df["Price"].dtype

# %%
df['Category'].isnull(df['Category'].mode()[0],inplace=True)
df

# %%
t= pd.to_datetime(df['Order_Date'],errors='coerce')
t

# %%
y=df.sort_values('Price',ascending=False)
y

# %%
def discount(x):
    if x >= 300:
        print("expensive")
    else:
        print("cheap")

# %%
df['discount'] = df['Price'].apply(discount)

# %%
df["Quantity"]=pd.to_numeric(df["Quantity"],errors='coerce')
df["Quantity"].dtype
# Out:
# dtype('float64')

# %%
(df["Quantity"]<0).sum()
# Out:
# np.int64(2)

# %%
df["Quantity"] = df["Quantity"].abs()#changing
df
# Out:
#       ID  Customer_Name   Order_ID  Order_Date        Product     Category  \
# 0    100   Customer_100  ORD-41285  11/22/2024        Blender         Home
# 2    102   Customer_102  ORD-84355  12/23/2024  Tennis Racket       Sports
# 3    103   Customer_103  ORD-57811   3/19/2025        Science        Books
# 4    104   Customer_104  ORD-93614  10/20/2025      Biography        Books
# 5    105   Customer_105  ORD-22442  11/20/2024  Tennis Racket       Sports
# ..   ...            ...        ...         ...            ...          ...
# 97   197   Customer_197  ORD-79139   6/23/2025        Blender         Home
# 98   198   Customer_198  ORD-14608   7/27/2025         Vacuum          NaN
# 99   199   Customer_199  ORD-82922   1/22/2025        Blender         Home
# 100  175   Customer_175  ORD-56651   2/24/2025     Headphones  Electronics
# 102  146   Customer_146  ORD-32755    7/9/2025     Basketball   electronic
#
#      Quantity   Price    Payment_Method      Status     Total discount
# 0         3.0   38.00  Cash on Delivery     Shipped   114.000     None
# 2         1.0  389.05            PayPal   Delivered   389.050     None
# 3         5.0  233.92            PayPal  Processing  1169.600     None
# 4         1.0  552.51  Cash on Delivery  Processing   552.510     None
# 5         3.0  122.06  Cash on Delivery   Cancelled   366.180     None
# ..        ...     ...               ...         ...       ...      ...
# 97        1.0  160.16            PayPal   Cancelled   160.160     None
# 98        2.0  497.01  Cash on Delivery     Shipped   994.020     None
# 99        5.0  372.28       Credit Card     Shipped  1861.400     None
# 100       1.0  111.36       Credit Card  Processing    77.952     None
# 102       2.0  705.42     Bank Transfer  Processing  1410.840     None
#
# [100 rows x 12 columns]

# %%
df.groupby("Category")["Price"].mean()

# %%
pd.merge(df, df2, on='Category')

# %%
df.columns
type(df)
