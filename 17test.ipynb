# %% [markdown]
# PROGRAMMING ASSIGNMENT
# Student Record Management System (CRUD) – Python
# OBJECTIVE:
# Design and implement a console-based Student Record
# Management System that performs CRUD operations using:
#
# • Functions
# • Loops
# • Conditional statements
# • Data types
# • Operators
#
#
# PROBLEM STATEMENT:
#
# Create a Python program to manage student records.
#
# Each student record must contain:
#
# {
#     "id": int,
#     "name": str,
#     "age": int,
#     "marks": float
# }
#
# All records must be stored inside a list.
#
#
# FUNCTIONAL REQUIREMENTS:
#
# You must implement the following functions:
#
# 1) Add Student
#    def add_student(students):
#
#    - Take input from the user
#    - Validate:
#        Age must be > 0
#        Marks must be between 0 and 100
#    - Add the student to the list
#
# 2) View Students
#    def view_students(students):
#
#    - Display all students
#    - If no records exist, display a message
#
# 3) Update Student
#    def update_student(students):
#
#    - Ask for student ID
#    - If found:
#        Allow updating name, age, or marks
#    - If not found:
#        Display error message
#
# 4) Delete Student
#    def delete_student(students):
#
#    - Ask for student ID
#    - Remove the student if found
#    - Otherwise display error message
#
#
# 5) ADDITIONAL REQUIREMENTS (MANDATORY)
#
# Implement:
#
# - Search student by name
# - Calculate average marks of all students
# - Display topper (student with highest marks)
#
# MENU STRUCTURE:
#
# Use a while loop to repeatedly display:
#
# 1. Add Student
# 2. View Students
# 3. Update Student
# 4. Delete Student
# 5. Search Student
# 6. Calculate Average Marks
# 7. Show Topper
# 8. Exit
#
# Use if-elif-else statements to handle user choices.
#
# TECHNICAL CONSTRAINTS:
#
# Students must:
#
# - Use at least 5 functions
# - Use at least one while loop
# - Use comparison operators (==, >, <, etc.)
# - Use logical operators (and, or)
# - Use list and dictionary data structures
# - Use arithmetic operators for calculations

# %%
students=[] 
def add_student(students):
       stu_id = input("enter id")
       name = input("Enter student name: ")
       age=int(input("enter age:"))
       marks = float(input("enter marks:"))
       if age > 0 and marks <= 100:
        student = {
            "id":  stu_id,
            "name": name,
            "age": age,
            "marks": marks,
        }
        students.append(student)
        print("Student added successfully.")
       else:
        print("Invalid input.")

# %%
def view_students(students):
    if not students:
        print("No students available.")
    else:
        print("Available students:")
        for student in students:
            print("ID:", student["id"])
            print("Name:", student["name"])
            print("Age:", student["age"])
            print("Marks:", student["marks"])

# %%
def update_student(students):
    student_id = int(input("Enter Student ID to update: "))

    for student in students:
        if student["id"] == student_id:
            print("Student Found")

            student["name"] = input("Enter New Name: ")
            student["age"] = int(input("Enter New Age: "))
            student["marks"] = float(input("Enter New Marks: "))

            if student["age"] > 0 and 0 <= student["marks"] <= 100:
                print("Student updated successfully")
            else:
                print("Invalid Age or Marks;")
            return

    print("Student ID not foun;.")

# %%
def search_student(students):
    name = input("Enter student name to search: ")
    
    for student in students:
        if student["name"] == name:
            print("ID:", student["id"])
            print("Name:", student["name"])
            print("Age:", student["age"])
            print("Marks:", student["marks"])
            

    else:
        print("Student not found.")

# %%
students=[{'id':1,'name':'As','age':22,'marks':88},
          {'id':2,'name':'kk','age':21,'marks':82},
          {'id':3,'name':'rr','age':20,'marks':78},
          {'id':4,'name':'vv','age':23,'marks':98},]

# %%
def avg_student(students):
    total =0
    for student in students:
        total += student['marks']
        avg=total/len(students)
    print('average marks',avg)

# %%
avg_student(students)
# Out:
# average marks 86.5

# %%
def top_student(students):
    for student in students:
        topper=students[0]
        if student["marks"] >topper['marks']:
            topper =student
    print("Topper student:")
    print("ID:", topper["id"])
    print("Name:", topper["name"])
    print("Age:", topper["age"])
    print("Marks:", topper["marks"])

# %%
top_student(students)
# Out:
# Topper student:
# ID: 4
# Name: vv
# Age: 23
# Marks: 98

# %% [markdown]
# 1. Add Student
# 2. View Students
# 3. Update Student
# 4. Delete Student
# 5. Search Student
# 6. Calculate Average Marks
# 7. Show Topper
# 8. Exit

# %%
def delete_student(students):
    for student in students:

# %%
while True:
    print("1. Add Student")
    print("2. View Students")
    print("3. Update Student")
    print("4. Delete Student")
    print("5. Search Student")
    print("6. Calculate Average Marks")
    print("7. Show Topper")
    print("8. Exit")

    choice = input("Enter your choice: ")

    if choice == '1':
       add_student(students)
    elif choice == '2':
        view_students(students)
    elif choice == '3':
        update_student(students)

    elif choice == '5':
        search_student(students)
    elif choice == '6':
        avg_student(students)
    elif choice == '7':
        top_student(students)
    elif choice =='8':
        print("exit ")
        break
    else:
        print('invalid choice')
# Out:
# 1. Add Student
# 2. View Students
# 3. Update Student
# 4. Delete Student
# 5. Search Student
# 6. Calculate Average Marks
# 7. Show Topper
# 8. Exit
# Topper student:
# ID: 4
# Name: vv
# Age: 23
# Marks: 98
# 1. Add Student
# 2. View Students
# 3. Update Student
# 4. Delete Student
# 5. Search Student
# 6. Calculate Average Marks
# 7. Show Topper
# 8. Exit
# exit

# %%
students=[]
def add_student(students):
    id=int(input("Enter ID : "))
    name=input("Enter Name: ")
    age=int(input("Enter Age : "))
    marks=int(input("Enter Marks : "))
    while age<0:
        print("Invalid Age")
        age=int(input("Enter age Again : "))
    while marks<0 or marks>100:
        print("Enter Correct Marks.")
        marks=int(input("Enter Marks again : "))
    student={
        'id':id,
        'name':name,
        'age':age,
        'marks':marks
    }
    students.append(student)
    print("Student Added Successfully.")
    students()

# %%
while True:
    print("1. Add Student\n2. Exit")
    opt=int(input("Enter the option to continue >>> "))
    if opt==1:
        add_student(students)
    elif opt==2:
        break
# Out:
# 1. Add Student
# 2. Exit
