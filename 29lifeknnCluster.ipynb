# %%
import pandas as pd

# %%
data=pd.read_csv(r'C:\Users\kashi\OneDrive\图片\Desktop\techcadd\gene_expression.csv')
data
# Out:
#       Gene One  Gene Two  Cancer Present
# 0          4.3       3.9               1
# 1          2.5       6.3               0
# 2          5.7       3.9               1
# 3          6.1       6.2               0
# 4          7.4       3.4               1
# ...        ...       ...             ...
# 2995       5.0       6.5               1
# 2996       3.4       6.6               0
# 2997       2.7       6.5               0
# 2998       3.3       5.6               0
# 2999       4.6       8.2               0
#
# [3000 rows x 3 columns]

# %%
data.isna().sum()
# Out:
# Gene One          0
# Gene Two          0
# Cancer Present    0
# dtype: int64

# %%
x=data[['Gene One','Gene Two']]

# %%
y=data['Cancer Present']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
ss_scaled =ss.fit_transform(x)
ss_scaled
# Out:
# array([[-0.71120047, -0.87371191],
#        [-1.6958386 ,  0.51454023],
#        [ 0.05462918, -0.87371191],
#        ...,
#        [-1.58643436,  0.63022791],
#        [-1.25822165,  0.10963336],
#        [-0.54709412,  1.61357318]], shape=(3000, 2))

# %%
from sklearn.neighbors import KNeighborsClassifier
kc = KNeighborsClassifier()

# %%
kc.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
pre = kc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pre)
# Out:
# 0.9366666666666666

# %%
from sklearn.cluster import KMeans
km = KMeans(n_clusters=5)
km.fit(ss_scaled)
# Out:
# KMeans(n_clusters=5)

# %%
pre = kc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pre)
# Out:
# 0.9366666666666666
