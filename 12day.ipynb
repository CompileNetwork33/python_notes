# %%
import numpy as np
list = [10,44,34,0]
p = np.array(list)
print(p)
# Out:
# [10 44 34  0]

# %%
p.sum()
# Out:
# np.int64(88)

# %%
p.all()
# Out:
# np.False_

# %%
p.copy()
# Out:
# array([10, 44, 34])

# %%
p.mean()
# Out:
# np.float64(29.333333333333332)

# %%
p.dtype
# Out:
# dtype('int64')

# %%
p.ndim
# Out:
# 1

# %%
p.cumsum()
# Out:
# array([10, 54, 88])

# %%
p.nonzero()
# Out:
# (array([0, 1, 2]),)

# %%
p.size
# Out:
# 3

# %%
p.data

# %%
p.itemsize
# Out:
# 8
