# %%
import numpy as np
list = [10,44,34,0]
p = np.array(list)
print(p)
# Out:
# [10 44 34  0]

# %%
p.sum()
# Out:
# np.int64(88)

# %%
p.all()
# Out:
# np.False_

# %%
p.copy()
# Out:
# array([10, 44, 34,  0])

# %%
p.mean()
# Out:
# np.float64(22.0)

# %%
p.dtype
# Out:
# dtype('int64')

# %%
p.ndim
# Out:
# 1

# %%
p.cumsum()
# Out:
# array([10, 54, 88, 88])

# %%
p.nonzero()
# Out:
# (array([0, 1, 2]),)

# %%
p.size
# Out:
# 4

# %%
p.data

# %%
p.itemsize
# Out:
# 8

# %%
list =np.array([[[2,3,5],[4,6,7],[3,8,9]],[[4,8,9],[8,4,6],[5,1,9]]])
list
#list.ndim
# Out:
# array([[[2, 3, 5],
#         [4, 6, 7],
#         [3, 8, 9]],
#
#        [[4, 8, 9],
#         [8, 4, 6],
#         [5, 1, 9]]])

# %%
list.shape
# Out:
# (2, 3, 3)

# %%
list[0][1][1]
# Out:
# np.int64(6)

# %%
list[1][1][2]
# Out:
# np.int64(6)

# %%
list[0,1:,:-1]
# Out:
# array([[4, 6],
#        [3, 8]])

# %%
list[:,1]
# Out:
# array([[[2, 3, 5],
#         [4, 6, 7],
#         [3, 8, 9]]])
